# %%
import bs4
import pymupdf

# %%
### TEXT LOADER

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("speech.txt")

# %%
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='“I join my other colleagues in congratulating the Prime Minister of Pakistan on his taking over as Chairman of SAARC. I would like to convey our sincere appreciation to the Government of Pakistan for the excellent arrangements made for this Summit, and for the warm hospitality extended to our delegation.\n\nI also join other delegations in commending the immediate past Chairman – Nepal – for the energy and dedication with which it guided SAARC activities during these last two years. This was in spite of the many important domestic preoccupations of His Majesty’s Government of Nepal. The spadework for many of today’s successful outcomes was done in the various meetings of Ministers and officials in Kathmandu.\n\nAt the last Summit in Kathmandu, I had said that, at sixteen years of age, SAARC needed a dose of economic and social realism to move from adolescence to adulthood. Our organization is now 18 years old. I think we can 
# ...

# %% [markdown]
# READING A PDF FILE

# %%
from langchain_community.document_loaders import PyPDFLoader
loader_pdf=PyPDFLoader("RAG.pdf")
docs = loader_pdf.load()
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m133 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Retrieval Augmented Generation (RAG) for Everyone', 'source': 'RAG.pdf', 'total_pages': 57, 'page': 0, 'page_label': '1'}, page_content='Created by Pavan Belagatti\nRetrieval\nAugmented\nGeneration\n(RAG)\nfor\nEveryone!\nWhat\nis\nRAG\n2\nRAG\nComponents\n3\nAdvantages\nof\nRetrieval\nAugmented\nGeneration\n3\nSystematic\nRAG\nWorkflow\n4\nRAG\nRetrieval\nSources\n6\nRAG\nTutorial\n7\nEvolution\nof\nRAG\nOver\nTime\n8\nRAG\nDesign\nChoices\n9\nChunking\nStrategies\nin\nRAG\n10\nRAG\nUsing\nLangChain\n12\nAdvanced\nRAG\n13\nReranking\nin\nRAG\n14\nTypes\nof\nEmbedding\nModels\nfor\nRAG\n16\nSemantic\nChunking\nin\nRAG\nApplications\n18\nRetrieval\nPain\nPoints\nin\nRAG\n19\nRAG\nEnhancement\nTechniques\n21\nRAG\nBest\nPractices\n23\nSemantic\nCache\nto\nImprove\nRAG\n24\nImproving\nRAG\nPipeline\n26\nMetrics\nfor\nRAG\nPerformance\n27\nRAG\nApproaches\n29\nAdvanced\
# ...

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# WEB BASED LOADER

# %%
from langchain_community.document_loaders import WebBaseLoader
loader_web = WebBaseLoader(web_paths=["https://www.geeksforgeeks.org/what-is-data-science/"],
                           bs_kwargs=dict(parse_only=bs4.SoupStrainer(class_="footer"))).load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader_web
# Out:
# [Document(metadata={'source': 'https://www.geeksforgeeks.org/what-is-data-science/'}, page_content='')]

# %%
### ARXIV LOADER

# %%
from langchain_community.document_loaders import WikipediaLoader
wiki_loader = WikipediaLoader(query="Data_science",lang="en",load_max_docs=1)
docs = wiki_loader.load()
docs
# Out:
# [Document(metadata={'title': 'Data science', 'summary': 'Data science is an interdisciplinary academic field that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms, coding (like Python, SQL, and R), and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data. A data scientist is a professional who creates programming code and combines it with statistical knowledge to summarize data.\n\n', 'source': 'https://en.wikipedia.org/wiki/Data_science'}, page_content='Data science is an interdisciplinary academic field that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms, coding (like Python, SQL, and R), and systems to extract or extrapolate knowledge from potentially noisy, structured, or unstructured data. A data scientist is a professional who creates programming code and combines it with statistical knowledge to summarize data.\
# ...

# %% [markdown]
# TEXT SPLITTING

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("RAG.pdf")
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m133 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Retrieval Augmented Generation (RAG) for Everyone', 'source': 'RAG.pdf', 'total_pages': 57, 'page': 0, 'page_label': '1'}, page_content='Created by Pavan Belagatti\nRetrieval\nAugmented\nGeneration\n(RAG)\nfor\nEveryone!\nWhat\nis\nRAG\n2\nRAG\nComponents\n3\nAdvantages\nof\nRetrieval\nAugmented\nGeneration\n3\nSystematic\nRAG\nWorkflow\n4\nRAG\nRetrieval\nSources\n6\nRAG\nTutorial\n7\nEvolution\nof\nRAG\nOver\nTime\n8\nRAG\nDesign\nChoices\n9\nChunking\nStrategies\nin\nRAG\n10\nRAG\nUsing\nLangChain\n12\nAdvanced\nRAG\n13\nReranking\nin\nRAG\n14\nTypes\nof\nEmbedding\nModels\nfor\nRAG\n16\nSemantic\nChunking\nin\nRAG\nApplications\n18\nRetrieval\nPain\nPoints\nin\nRAG\n19\nRAG\nEnhancement\nTechniques\n21\nRAG\nBest\nPractices\n23\nSemantic\nCache\nto\nImprove\nRAG\n24\nImproving\nRAG\nPipeline\n26\nMetrics\nfor\nRAG\nPerformance\n27\nRAG\nApproaches\n29\nAdvanced\
# ...

# %% [markdown]
# ### How to recursively split text by characters, words, and sentences using RecursiveCharacterTextSplitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_docs=text_splitter.split_documents(docs)
final_docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m133 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Retrieval Augmented Generation (RAG) for Everyone', 'source': 'RAG.pdf', 'total_pages': 57, 'page': 0, 'page_label': '1'}, page_content='Created by Pavan Belagatti\nRetrieval\nAugmented\nGeneration\n(RAG)\nfor\nEveryone!\nWhat\nis\nRAG\n2\nRAG\nComponents\n3\nAdvantages\nof\nRetrieval\nAugmented\nGeneration\n3\nSystematic\nRAG\nWorkflow\n4\nRAG\nRetrieval\nSources\n6\nRAG\nTutorial\n7\nEvolution\nof\nRAG\nOver\nTime\n8\nRAG\nDesign\nChoices\n9\nChunking\nStrategies\nin\nRAG\n10\nRAG\nUsing\nLangChain\n12\nAdvanced\nRAG\n13\nReranking\nin\nRAG\n14\nTypes\nof\nEmbedding\nModels\nfor\nRAG\n16\nSemantic\nChunking\nin\nRAG\nApplications\n18\nRetrieval\nPain\nPoints\nin\nRAG\n19\nRAG\nEnhancement\nTechniques\n21'),
# ...

# %%
text = ""
with open("speech.txt") as f:
    text = f.read() ;

text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=10)
text_docs = text_splitter.create_documents([text])

# %%
html_text = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>My First Web Page</title>
</head>
<body>

    <h1>Welcome to My Website</h1>
    <p>This is a simple paragraph of text describing the page.</p>

    <!-- This is a comment: An image example -->
    <img src="https://placeholder.com" alt="A descriptive placeholder image">

    <!-- A link example -->
    <p>Visit the official <a href="https://www.w3schools.com" target="_blank">W3Schools Website</a> to learn more.</p>

</body>
</html>
"""
from langchain_text_splitters import HTMLHeaderTextSplitter
headers_to_split_on=[("h1","Header1")]
HTML_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
HTML_splitter.split_text(html_text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 25
#      21 </html>
#      22 """
#      23 from langchain_text_splitters import HTMLHeaderTextSplitter
#      24 headers_to_split_on=[("h1","Header1"),("p","Paragraph"),("img","Image")]
# ---> 25 HTML_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
#      26 HTML_splitter.split_text(html_text)
#
# File ~/anaconda3/envs/ds/lib/python3.14/site-packages/langchain_text_splitters/html.py:122, in HTMLHeaderTextSplitter.__init__(self, headers_to_split_on, return_each_element)
#     108 """Initialize with headers to split on.
#     109
#     110 Args:
#    (...)    119         aggregated into fewer Documents.
#     120 """
#     121 # Sort headers by their numeric level so that h1 < h2 < h3...
# --> 122 self.headers_to_split_on = sorted(
# ...
